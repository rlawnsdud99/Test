# %%
import tensorflow as tf
import numpy as np
x_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float)
y_data = np.array([[0], [1], [1], [0]], dtype=np.float)
#XOR은 x,y가 같을경우 0을, 다를경우 1을 출력하므로 그에 해당하는 정답 데이터 를 만든다
#X가 입력, Y가 출력이다.

#Keras를 이용해 간편히 모델을 만든다. 
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(16, input_shape=(2,), activation='sigmoid'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
#Dense 층을 2개 이용하여 네트워크를 구성하고. activation은 sigmoid로 이용한다.

#옵티마이저는 SGD를 이용한다. 
SGD = tf.keras.optimizers.SGD(lr=1.5)

#모델, loss func 평가 방법 등등을 모델에 컴파일한다.
model.compile(optimizer=SGD, loss='mse', metrics=['accuracy'])

#모델을 500회 학습시킨다.
model.fit(x_data, y_data, epochs=500)

#모델을 평가하고 정답지에 대한 출력을 실험해본다.
model.evaluate(x_data, y_data)
predict = model.predict(x_data)
print(predict)
# Out:
# WARNING:tensorflow:From C:\Users\rlawn\anaconda3\envs\study1\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Train on 4 samples
# Epoch 1/500
# 4/4 [==============================] - 0s 9ms/sample - loss: 0.2522 - acc: 0.5000
# Epoch 2/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2502 - acc: 0.5000
# Epoch 3/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2501 - acc: 0.5000
# C:\Users\rlawn\anaconda3\envs\study1\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\rlawn\anaconda3\envs\study1\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   after removing the cwd from sys.path.
# Epoch 4/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2501 - acc: 0.5000
# Epoch 5/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2501 - acc: 0.5000
# Epoch 6/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2501 - acc: 0.5000
# Epoch 7/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2501 - acc: 0.5000
# Epoch 8/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2501 - acc: 0.5000
# Epoch 9/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2501 - acc: 0.5000
# Epoch 10/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2501 - acc: 0.5000
# Epoch 11/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2501 - acc: 0.5000
# Epoch 12/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2501 - acc: 0.5000
# Epoch 13/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2501 - acc: 0.5000
# Epoch 14/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2501 - acc: 0.5000
# Epoch 15/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2500 - acc: 0.5000
# Epoch 16/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2500 - acc: 0.5000
# Epoch 17/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2500 - acc: 0.5000
# Epoch 18/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2500 - acc: 0.5000
# Epoch 19/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2500 - acc: 0.5000
# Epoch 20/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2500 - acc: 0.5000
# Epoch 21/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2500 - acc: 0.5000
# Epoch 22/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2500 - acc: 0.5000
# Epoch 23/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2500 - acc: 0.5000
# Epoch 24/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2500 - acc: 0.5000
# Epoch 25/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2500 - acc: 0.5000
# Epoch 26/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2500 - acc: 0.5000
# Epoch 27/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2500 - acc: 0.5000
# Epoch 28/500
# 4/4 [==============================] - 0s 750us/sample - loss: 0.2500 - acc: 0.5000
# Epoch 29/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2500 - acc: 0.5000
# Epoch 30/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2499 - acc: 0.5000
# Epoch 31/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2499 - acc: 0.5000
# Epoch 32/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2499 - acc: 0.5000
# Epoch 33/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2499 - acc: 0.5000
# Epoch 34/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2499 - acc: 0.5000
# Epoch 35/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2499 - acc: 0.5000
# Epoch 36/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2499 - acc: 0.5000
# Epoch 37/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2499 - acc: 0.5000
# Epoch 38/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2499 - acc: 0.5000
# Epoch 39/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2499 - acc: 0.5000
# Epoch 40/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2499 - acc: 0.5000
# Epoch 41/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2499 - acc: 0.5000
# Epoch 42/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2499 - acc: 0.5000
# Epoch 43/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2499 - acc: 0.5000
# Epoch 44/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2499 - acc: 0.5000
# Epoch 45/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2499 - acc: 0.5000
# Epoch 46/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2499 - acc: 0.5000
# Epoch 47/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2499 - acc: 0.5000
# Epoch 48/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2498 - acc: 0.5000
# Epoch 49/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2498 - acc: 0.5000
# Epoch 50/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2498 - acc: 0.5000
# Epoch 51/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2498 - acc: 0.5000
# Epoch 52/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2498 - acc: 0.5000
# Epoch 53/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2498 - acc: 0.5000
# Epoch 54/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2498 - acc: 0.5000
# Epoch 55/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2498 - acc: 0.5000
# Epoch 56/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2498 - acc: 0.5000
# Epoch 57/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2498 - acc: 0.5000
# Epoch 58/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2498 - acc: 0.5000
# Epoch 59/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2498 - acc: 0.5000
# Epoch 60/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2498 - acc: 0.5000
# Epoch 61/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2498 - acc: 0.5000
# Epoch 62/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2498 - acc: 0.5000
# Epoch 63/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2498 - acc: 0.5000
# Epoch 64/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2498 - acc: 0.5000
# Epoch 65/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2498 - acc: 0.5000
# Epoch 66/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2498 - acc: 0.5000
# Epoch 67/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2497 - acc: 0.5000
# Epoch 68/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2497 - acc: 0.5000
# Epoch 69/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2497 - acc: 0.5000
# Epoch 70/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2497 - acc: 0.5000
# Epoch 71/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2497 - acc: 0.5000
# Epoch 72/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2497 - acc: 0.5000
# Epoch 73/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2497 - acc: 0.5000
# Epoch 74/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2497 - acc: 0.5000
# Epoch 75/500
# 4/4 [==============================] - 0s 750us/sample - loss: 0.2497 - acc: 0.5000
# Epoch 76/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2497 - acc: 0.5000
# Epoch 77/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2497 - acc: 0.5000
# Epoch 78/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2497 - acc: 0.5000
# Epoch 79/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2497 - acc: 0.5000
# Epoch 80/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2497 - acc: 0.5000
# Epoch 81/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2497 - acc: 0.5000
# Epoch 82/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2497 - acc: 0.5000
# Epoch 83/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2497 - acc: 0.5000
# Epoch 84/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2497 - acc: 0.5000
# Epoch 85/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2497 - acc: 0.5000
# Epoch 86/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2496 - acc: 0.5000
# Epoch 87/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2496 - acc: 0.5000
# Epoch 88/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2496 - acc: 0.5000
# Epoch 89/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2496 - acc: 0.5000
# Epoch 90/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2496 - acc: 0.5000
# Epoch 91/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2496 - acc: 0.5000
# Epoch 92/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2496 - acc: 0.5000
# Epoch 93/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2496 - acc: 0.5000
# Epoch 94/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2496 - acc: 0.5000
# Epoch 95/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2496 - acc: 0.5000
# Epoch 96/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2496 - acc: 0.5000
# Epoch 97/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2496 - acc: 0.5000
# Epoch 98/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2496 - acc: 0.5000
# Epoch 99/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2496 - acc: 0.5000
# Epoch 100/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2496 - acc: 0.5000
# Epoch 101/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2496 - acc: 0.5000
# Epoch 102/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2496 - acc: 0.5000
# Epoch 103/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2496 - acc: 0.5000
# Epoch 104/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2495 - acc: 0.5000
# Epoch 105/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2495 - acc: 0.5000
# Epoch 106/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2495 - acc: 0.5000
# Epoch 107/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2495 - acc: 0.5000
# Epoch 108/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2495 - acc: 0.5000
# Epoch 109/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2495 - acc: 0.5000
# Epoch 110/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2495 - acc: 0.5000
# Epoch 111/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2495 - acc: 0.5000
# Epoch 112/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2495 - acc: 0.5000
# Epoch 113/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2495 - acc: 0.5000
# Epoch 114/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2495 - acc: 0.5000
# Epoch 115/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2495 - acc: 0.5000
# Epoch 116/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2495 - acc: 0.5000
# Epoch 117/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2495 - acc: 0.5000
# Epoch 118/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2495 - acc: 0.5000
# Epoch 119/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2495 - acc: 0.5000
# Epoch 120/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2495 - acc: 0.5000
# Epoch 121/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2494 - acc: 0.5000
# Epoch 122/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2494 - acc: 0.5000
# Epoch 123/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2494 - acc: 0.5000
# Epoch 124/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2494 - acc: 0.5000
# Epoch 125/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2494 - acc: 0.5000
# Epoch 126/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2494 - acc: 0.5000
# Epoch 127/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2494 - acc: 0.5000
# Epoch 128/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2494 - acc: 0.5000
# Epoch 129/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2494 - acc: 0.5000
# Epoch 130/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2494 - acc: 0.5000
# Epoch 131/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2494 - acc: 0.5000
# Epoch 132/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2494 - acc: 0.5000
# Epoch 133/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2494 - acc: 0.5000
# Epoch 134/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2494 - acc: 0.5000
# Epoch 135/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2493 - acc: 0.5000
# Epoch 136/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2493 - acc: 0.5000
# Epoch 137/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2493 - acc: 0.5000
# Epoch 138/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2493 - acc: 0.5000
# Epoch 139/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2493 - acc: 0.5000
# Epoch 140/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2493 - acc: 0.5000
# Epoch 141/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2493 - acc: 0.5000
# Epoch 142/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2493 - acc: 0.5000
# Epoch 143/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2493 - acc: 0.5000
# Epoch 144/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2493 - acc: 0.5000
# Epoch 145/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2493 - acc: 0.5000
# Epoch 146/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2493 - acc: 0.5000
# Epoch 147/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2492 - acc: 0.5000
# Epoch 148/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2492 - acc: 0.5000
# Epoch 149/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2492 - acc: 0.5000
# Epoch 150/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2492 - acc: 0.5000
# Epoch 151/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2492 - acc: 0.5000
# Epoch 152/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2492 - acc: 0.5000
# Epoch 153/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2492 - acc: 0.5000
# Epoch 154/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2492 - acc: 0.5000
# Epoch 155/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2492 - acc: 0.5000
# Epoch 156/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2492 - acc: 0.5000
# Epoch 157/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2492 - acc: 0.5000
# Epoch 158/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2491 - acc: 0.5000
# Epoch 159/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2491 - acc: 0.5000
# Epoch 160/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2491 - acc: 0.5000
# Epoch 161/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2491 - acc: 0.5000
# Epoch 162/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2491 - acc: 0.5000
# Epoch 163/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2491 - acc: 0.5000
# Epoch 164/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2491 - acc: 0.5000
# Epoch 165/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2491 - acc: 0.5000
# Epoch 166/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2491 - acc: 0.5000
# Epoch 167/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2490 - acc: 0.5000
# Epoch 168/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2490 - acc: 0.5000
# Epoch 169/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2490 - acc: 0.5000
# Epoch 170/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2490 - acc: 0.5000
# Epoch 171/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2490 - acc: 0.5000
# Epoch 172/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2490 - acc: 0.5000
# Epoch 173/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2490 - acc: 0.5000
# Epoch 174/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2490 - acc: 0.5000
# Epoch 175/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2490 - acc: 0.5000
# Epoch 176/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2489 - acc: 0.5000
# Epoch 177/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2489 - acc: 0.5000
# Epoch 178/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2489 - acc: 0.5000
# Epoch 179/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2489 - acc: 0.5000
# Epoch 180/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2489 - acc: 0.5000
# Epoch 181/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2489 - acc: 0.5000
# Epoch 182/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2489 - acc: 0.5000
# Epoch 183/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2488 - acc: 0.5000
# Epoch 184/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2488 - acc: 0.5000
# Epoch 185/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2488 - acc: 0.5000
# Epoch 186/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2488 - acc: 0.5000
# Epoch 187/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2488 - acc: 0.5000
# Epoch 188/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2488 - acc: 0.5000
# Epoch 189/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2488 - acc: 0.5000
# Epoch 190/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2487 - acc: 0.5000
# Epoch 191/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2487 - acc: 0.5000
# Epoch 192/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2487 - acc: 0.5000
# Epoch 193/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2487 - acc: 0.5000
# Epoch 194/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2487 - acc: 0.5000
# Epoch 195/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2487 - acc: 0.5000
# Epoch 196/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2486 - acc: 0.5000
# Epoch 197/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2486 - acc: 0.5000
# Epoch 198/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2486 - acc: 0.5000
# Epoch 199/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2486 - acc: 0.5000
# Epoch 200/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2486 - acc: 0.5000
# Epoch 201/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2486 - acc: 0.5000
# Epoch 202/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2485 - acc: 0.5000
# Epoch 203/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2485 - acc: 0.5000
# Epoch 204/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2485 - acc: 0.5000
# Epoch 205/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2485 - acc: 0.5000
# Epoch 206/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2485 - acc: 0.5000
# Epoch 207/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2484 - acc: 0.5000
# Epoch 208/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2484 - acc: 0.5000
# Epoch 209/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2484 - acc: 0.5000
# Epoch 210/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2484 - acc: 0.5000
# Epoch 211/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2483 - acc: 0.5000
# Epoch 212/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2483 - acc: 0.5000
# Epoch 213/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2483 - acc: 0.5000
# Epoch 214/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2483 - acc: 0.5000
# Epoch 215/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2483 - acc: 0.5000
# Epoch 216/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2482 - acc: 0.5000
# Epoch 217/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2482 - acc: 0.5000
# Epoch 218/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2482 - acc: 0.5000
# Epoch 219/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2482 - acc: 0.5000
# Epoch 220/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2481 - acc: 0.5000
# Epoch 221/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2481 - acc: 0.5000
# Epoch 222/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2481 - acc: 0.5000
# Epoch 223/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2480 - acc: 0.5000
# Epoch 224/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2480 - acc: 0.5000
# Epoch 225/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2480 - acc: 0.5000
# Epoch 226/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2480 - acc: 0.5000
# Epoch 227/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2479 - acc: 0.5000
# Epoch 228/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2479 - acc: 0.5000
# Epoch 229/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2479 - acc: 0.5000
# Epoch 230/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2478 - acc: 0.5000
# Epoch 231/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2478 - acc: 0.5000
# Epoch 232/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2478 - acc: 0.5000
# Epoch 233/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2477 - acc: 0.5000
# Epoch 234/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2477 - acc: 0.5000
# Epoch 235/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2477 - acc: 0.5000
# Epoch 236/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2476 - acc: 0.5000
# Epoch 237/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2476 - acc: 0.5000
# Epoch 238/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2476 - acc: 0.5000
# Epoch 239/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2475 - acc: 0.5000
# Epoch 240/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2475 - acc: 0.5000
# Epoch 241/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2474 - acc: 0.5000
# Epoch 242/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2474 - acc: 0.5000
# Epoch 243/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2474 - acc: 0.5000
# Epoch 244/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2473 - acc: 0.5000
# Epoch 245/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2473 - acc: 0.7500
# Epoch 246/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2472 - acc: 0.7500
# Epoch 247/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2472 - acc: 0.7500
# Epoch 248/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2472 - acc: 0.7500
# Epoch 249/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2471 - acc: 0.7500
# Epoch 250/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2471 - acc: 0.7500
# Epoch 251/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2470 - acc: 0.7500
# Epoch 252/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2470 - acc: 0.7500
# Epoch 253/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2469 - acc: 0.7500
# Epoch 254/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2469 - acc: 0.7500
# Epoch 255/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2468 - acc: 0.7500
# Epoch 256/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2468 - acc: 0.7500
# Epoch 257/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2467 - acc: 0.7500
# Epoch 258/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2467 - acc: 0.7500
# Epoch 259/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2466 - acc: 0.7500
# Epoch 260/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2465 - acc: 0.7500
# Epoch 261/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2465 - acc: 0.7500
# Epoch 262/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2464 - acc: 0.7500
# Epoch 263/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2464 - acc: 0.7500
# Epoch 264/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2463 - acc: 0.7500
# Epoch 265/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2462 - acc: 0.7500
# Epoch 266/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2462 - acc: 0.7500
# Epoch 267/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2461 - acc: 0.7500
# Epoch 268/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2461 - acc: 0.7500
# Epoch 269/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2460 - acc: 0.7500
# Epoch 270/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2459 - acc: 0.7500
# Epoch 271/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2459 - acc: 0.7500
# Epoch 272/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2458 - acc: 0.7500
# Epoch 273/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2457 - acc: 0.7500
# Epoch 274/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2456 - acc: 0.7500
# Epoch 275/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2456 - acc: 0.7500
# Epoch 276/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2455 - acc: 0.7500
# Epoch 277/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2454 - acc: 0.7500
# Epoch 278/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2453 - acc: 0.7500
# Epoch 279/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2452 - acc: 0.7500
# Epoch 280/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2452 - acc: 0.7500
# Epoch 281/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2451 - acc: 0.7500
# Epoch 282/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2450 - acc: 0.7500
# Epoch 283/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2449 - acc: 0.7500
# Epoch 284/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2448 - acc: 0.7500
# Epoch 285/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2447 - acc: 0.7500
# Epoch 286/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2446 - acc: 0.7500
# Epoch 287/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2445 - acc: 0.7500
# Epoch 288/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2444 - acc: 0.7500
# Epoch 289/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2443 - acc: 0.7500
# Epoch 290/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2442 - acc: 0.7500
# Epoch 291/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2441 - acc: 0.7500
# Epoch 292/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2440 - acc: 0.7500
# Epoch 293/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2439 - acc: 0.7500
# Epoch 294/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2438 - acc: 0.7500
# Epoch 295/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2437 - acc: 0.7500
# Epoch 296/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2436 - acc: 0.7500
# Epoch 297/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2435 - acc: 0.7500
# Epoch 298/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2434 - acc: 0.7500
# Epoch 299/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2432 - acc: 0.7500
# Epoch 300/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2431 - acc: 0.7500
# Epoch 301/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2430 - acc: 0.7500
# Epoch 302/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2429 - acc: 0.7500
# Epoch 303/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2427 - acc: 0.7500
# Epoch 304/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2426 - acc: 0.7500
# Epoch 305/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2425 - acc: 0.7500
# Epoch 306/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2423 - acc: 0.7500
# Epoch 307/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2422 - acc: 0.7500
# Epoch 308/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2421 - acc: 0.7500
# Epoch 309/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2419 - acc: 0.7500
# Epoch 310/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2418 - acc: 0.7500
# Epoch 311/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2416 - acc: 0.7500
# Epoch 312/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2415 - acc: 0.7500
# Epoch 313/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2413 - acc: 0.7500
# Epoch 314/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2412 - acc: 0.7500
# Epoch 315/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2410 - acc: 0.7500
# Epoch 316/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2408 - acc: 0.7500
# Epoch 317/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2407 - acc: 0.7500
# Epoch 318/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2405 - acc: 0.7500
# Epoch 319/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2403 - acc: 0.7500
# Epoch 320/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2402 - acc: 0.7500
# Epoch 321/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2400 - acc: 0.7500
# Epoch 322/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2398 - acc: 0.7500
# Epoch 323/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2396 - acc: 0.7500
# Epoch 324/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2394 - acc: 0.7500
# Epoch 325/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2392 - acc: 0.7500
# Epoch 326/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2390 - acc: 0.7500
# Epoch 327/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2388 - acc: 0.7500
# Epoch 328/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2386 - acc: 0.7500
# Epoch 329/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2384 - acc: 0.7500
# Epoch 330/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2382 - acc: 0.7500
# Epoch 331/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2380 - acc: 0.7500
# Epoch 332/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2378 - acc: 0.7500
# Epoch 333/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2376 - acc: 0.7500
# Epoch 334/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2373 - acc: 0.7500
# Epoch 335/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2371 - acc: 0.7500
# Epoch 336/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2369 - acc: 0.7500
# Epoch 337/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2367 - acc: 0.7500
# Epoch 338/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2364 - acc: 0.7500
# Epoch 339/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2362 - acc: 0.7500
# Epoch 340/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2359 - acc: 0.7500
# Epoch 341/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2357 - acc: 0.7500
# Epoch 342/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2354 - acc: 0.7500
# Epoch 343/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2352 - acc: 0.7500
# Epoch 344/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2349 - acc: 0.7500
# Epoch 345/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2346 - acc: 0.7500
# Epoch 346/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2343 - acc: 0.7500
# Epoch 347/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2341 - acc: 0.7500
# Epoch 348/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2338 - acc: 0.7500
# Epoch 349/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2335 - acc: 0.7500
# Epoch 350/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2332 - acc: 0.7500
# Epoch 351/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2329 - acc: 0.7500
# Epoch 352/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2326 - acc: 0.7500
# Epoch 353/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2323 - acc: 0.7500
# Epoch 354/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2320 - acc: 0.7500
# Epoch 355/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2317 - acc: 0.7500
# Epoch 356/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2314 - acc: 0.7500
# Epoch 357/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2310 - acc: 0.7500
# Epoch 358/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2307 - acc: 0.7500
# Epoch 359/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2304 - acc: 0.7500
# Epoch 360/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2300 - acc: 0.7500
# Epoch 361/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2297 - acc: 0.7500
# Epoch 362/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2293 - acc: 0.7500
# Epoch 363/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2290 - acc: 0.7500
# Epoch 364/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2286 - acc: 0.7500
# Epoch 365/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2282 - acc: 0.7500
# Epoch 366/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2278 - acc: 0.7500
# Epoch 367/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2275 - acc: 0.7500
# Epoch 368/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2271 - acc: 0.7500
# Epoch 369/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2267 - acc: 0.7500
# Epoch 370/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2263 - acc: 0.7500
# Epoch 371/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2259 - acc: 0.7500
# Epoch 372/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2255 - acc: 0.7500
# Epoch 373/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2250 - acc: 0.7500
# Epoch 374/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2246 - acc: 0.7500
# Epoch 375/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2242 - acc: 0.7500
# Epoch 376/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2238 - acc: 0.7500
# Epoch 377/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2233 - acc: 0.7500
# Epoch 378/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2229 - acc: 0.7500
# Epoch 379/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2224 - acc: 0.7500
# Epoch 380/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2219 - acc: 0.7500
# Epoch 381/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2215 - acc: 0.7500
# Epoch 382/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2210 - acc: 0.7500
# Epoch 383/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2205 - acc: 0.7500
# Epoch 384/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2200 - acc: 0.7500
# Epoch 385/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2195 - acc: 0.7500
# Epoch 386/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2190 - acc: 0.7500
# Epoch 387/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2185 - acc: 0.7500
# Epoch 388/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2180 - acc: 0.7500
# Epoch 389/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2175 - acc: 0.7500
# Epoch 390/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2169 - acc: 0.7500
# Epoch 391/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2164 - acc: 0.7500
# Epoch 392/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2159 - acc: 0.7500
# Epoch 393/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2153 - acc: 0.7500
# Epoch 394/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2147 - acc: 0.7500
# Epoch 395/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2142 - acc: 0.7500
# Epoch 396/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2136 - acc: 0.7500
# Epoch 397/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2130 - acc: 0.7500
# Epoch 398/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2124 - acc: 0.7500
# Epoch 399/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2118 - acc: 0.7500
# Epoch 400/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2112 - acc: 0.7500
# Epoch 401/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2106 - acc: 0.7500
# Epoch 402/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2100 - acc: 0.7500
# Epoch 403/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2094 - acc: 0.7500
# Epoch 404/500
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.2088 - acc: 0.7500
# Epoch 405/500
# 4/4 [==============================] - 0s 750us/sample - loss: 0.2081 - acc: 0.7500
# Epoch 406/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2075 - acc: 0.7500
# Epoch 407/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2068 - acc: 0.7500
# Epoch 408/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2062 - acc: 0.7500
# Epoch 409/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2055 - acc: 0.7500
# Epoch 410/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2048 - acc: 0.7500
# Epoch 411/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2042 - acc: 0.7500
# Epoch 412/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2035 - acc: 0.7500
# Epoch 413/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.2028 - acc: 0.7500
# Epoch 414/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.2021 - acc: 0.7500
# Epoch 415/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2014 - acc: 0.7500
# Epoch 416/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.2007 - acc: 0.7500
# Epoch 417/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1999 - acc: 0.7500
# Epoch 418/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1992 - acc: 0.7500
# Epoch 419/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1985 - acc: 0.7500
# Epoch 420/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.1977 - acc: 0.7500
# Epoch 421/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.1970 - acc: 0.7500
# Epoch 422/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1962 - acc: 0.7500
# Epoch 423/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1955 - acc: 0.7500
# Epoch 424/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1947 - acc: 0.7500
# Epoch 425/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1939 - acc: 0.7500
# Epoch 426/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1931 - acc: 0.7500
# Epoch 427/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1924 - acc: 0.7500
# Epoch 428/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.1916 - acc: 0.7500
# Epoch 429/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1908 - acc: 0.7500
# Epoch 430/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1899 - acc: 0.7500
# Epoch 431/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1891 - acc: 0.7500
# Epoch 432/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1883 - acc: 0.7500
# Epoch 433/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1875 - acc: 0.7500
# Epoch 434/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1867 - acc: 0.7500
# Epoch 435/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1858 - acc: 0.7500
# Epoch 436/500
# 4/4 [==============================] - 0s 750us/sample - loss: 0.1850 - acc: 0.7500
# Epoch 437/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1841 - acc: 0.7500
# Epoch 438/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.1833 - acc: 0.7500
# Epoch 439/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.1824 - acc: 0.7500
# Epoch 440/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1815 - acc: 0.7500
# Epoch 441/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1807 - acc: 0.7500
# Epoch 442/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1798 - acc: 0.7500
# Epoch 443/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.1789 - acc: 0.7500
# Epoch 444/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.1780 - acc: 0.7500
# Epoch 445/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1771 - acc: 0.7500
# Epoch 446/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.1762 - acc: 0.7500
# Epoch 447/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1753 - acc: 0.7500
# Epoch 448/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1744 - acc: 0.7500
# Epoch 449/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1735 - acc: 0.7500
# Epoch 450/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1726 - acc: 0.7500
# Epoch 451/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1717 - acc: 0.7500
# Epoch 452/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.1707 - acc: 0.7500
# Epoch 453/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1698 - acc: 0.7500
# Epoch 454/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1689 - acc: 0.7500
# Epoch 455/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1679 - acc: 0.7500
# Epoch 456/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1670 - acc: 1.0000
# Epoch 457/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1660 - acc: 1.0000
# Epoch 458/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.1651 - acc: 1.0000
# Epoch 459/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1641 - acc: 1.0000
# Epoch 460/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1632 - acc: 1.0000
# Epoch 461/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1622 - acc: 1.0000
# Epoch 462/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1612 - acc: 1.0000
# Epoch 463/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1603 - acc: 1.0000
# Epoch 464/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1593 - acc: 1.0000
# Epoch 465/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1583 - acc: 1.0000
# Epoch 466/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.1573 - acc: 1.0000
# Epoch 467/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.1563 - acc: 1.0000
# Epoch 468/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.1554 - acc: 1.0000
# Epoch 469/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1544 - acc: 1.0000
# Epoch 470/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.1534 - acc: 1.0000
# Epoch 471/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.1524 - acc: 1.0000
# Epoch 472/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1514 - acc: 1.0000
# Epoch 473/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1504 - acc: 1.0000
# Epoch 474/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.1494 - acc: 1.0000
# Epoch 475/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1484 - acc: 1.0000
# Epoch 476/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1474 - acc: 1.0000
# Epoch 477/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1464 - acc: 1.0000
# Epoch 478/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.1453 - acc: 1.0000
# Epoch 479/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1443 - acc: 1.0000
# Epoch 480/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.1433 - acc: 1.0000
# Epoch 481/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1423 - acc: 1.0000
# Epoch 482/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1413 - acc: 1.0000
# Epoch 483/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.1403 - acc: 1.0000
# Epoch 484/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1392 - acc: 1.0000
# Epoch 485/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.1382 - acc: 1.0000
# Epoch 486/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.1372 - acc: 1.0000
# Epoch 487/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1362 - acc: 1.0000
# Epoch 488/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1352 - acc: 1.0000
# Epoch 489/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1342 - acc: 1.0000
# Epoch 490/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.1331 - acc: 1.0000
# Epoch 491/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1321 - acc: 1.0000
# Epoch 492/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1311 - acc: 1.0000
# Epoch 493/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1301 - acc: 1.0000
# Epoch 494/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1291 - acc: 1.0000
# Epoch 495/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.1280 - acc: 1.0000
# Epoch 496/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1270 - acc: 1.0000
# Epoch 497/500
# 4/4 [==============================] - 0s 500us/sample - loss: 0.1260 - acc: 1.0000
# Epoch 498/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1250 - acc: 1.0000
# Epoch 499/500
# 4/4 [==============================] - 0s 250us/sample - loss: 0.1240 - acc: 1.0000
# Epoch 500/500
# 4/4 [==============================] - 0s 0s/sample - loss: 0.1230 - acc: 1.0000
# 4/4 [==============================] - 0s 3ms/sample - loss: 0.1220 - acc: 1.0000
# [[0.26026723]
#  [0.6730043 ]
#  [0.64020365]
#  [0.4286364 ]]

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

#minist dataset을 불러온다
mnist = tf.keras.datasets.mnist

#입출력 구분, 학습용과 테스트용을 구분한다
(x_train, y_train), (x_test, y_test) = mnist.load_data() 

#출력데이터를 onehot형식으로 바꾼다(일렬 데이터로 변환).
#또한 입력은 0~1 사이의 값으로 정규화한다
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test) 
x_train, x_test = x_train/255.0, x_test/255.0
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape) 

#Sequential keras 모델을 만든다.
model = tf.keras.models.Sequential([
    #입력되는 이미지가 28*28의 형태이므로, Flatten을 통해 1차원 배열로 바꿔준다
    tf.keras.layers.Flatten(input_shape=(28,28)), 
    #DNN 네트워크를 만든다. Drop out을 추가하여, 과적합을 막는다.
    tf.keras.layers.Dense(128, activation='relu'), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='relu'), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax') 
])
#모델을 요약한다
model.summary()

#optimizer, loss function, 평가방식을 정하여 모델을 컴파일한다
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

#모델을 학습한다
model.fit(x_train, y_train, epochs=20, validation_data=(x_test, y_test), verbose=2) 

#모델을 평가한다
model.evaluate(x_test, y_test, verbose=2)

#랜덤이미지에 대해 적용해본다
random_image = x_test[np.random.choice(len(x_test))] 
test_image = np.expand_dims(random_image, axis = 0) 
predict = model.predict(test_image)
print('predict ',predict, np.argmax(predict, axis=1)) 
plt.imshow(test_image[0], cmap='Greys')
plt.show()

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
#minist dataset을 불러온다
mnist = tf.keras.datasets.mnist

#입출력 구분, 학습용과 테스트용을 구분한다
(x_train, y_train), (x_test, y_test) = mnist.load_data() 

#출력데이터를 onehot형식으로 바꾼다(일렬 데이터로 변환).
#또한 입력은 0~1 사이의 값으로 정규화한다
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test) 
x_train, x_test = x_train/255.0, x_test/255.0

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape) 

#Sequential keras 모델을 만든다.
model = tf.keras.models.Sequential([
    #CNN부분 2차원 이미지를 3차원 배열로 넣고, Conv filter를 이용해, 특징을 잡고, 
    #MaxPool을 통해 더 특징적인 부분을 볼수 있다.(ex)얼굴 전체를 보기보다, 코 눈 입을 볼수있게된다 )
    
    tf.keras.layers.Reshape((28,28,1),input_shape=(28,28)), 
    tf.keras.layers.Conv2D(filters=32,kernel_size=3, padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),

    tf.keras.layers.Conv2D(filters=64,kernel_size=3, padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
 
    tf.keras.layers.Conv2D(filters=128,kernel_size=3, padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    
    #DNN부분.뽑아진 특징들을 1차원으로 만들어 간단한 .DNN에 넣고, 끝에서 출력한다
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax') 
])

#모델을 요약한다
model.summary()

#optimizer, loss function, 평가방식을 정하여 모델을 컴파일한다
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

#학습한다
model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test), verbose=2) 
#학습된 모델을 평가한다
model.evaluate(x_test, y_test, verbose=2)

#학습된 모델과 가중치를 저장한다.
model.save('mnist_cnn.h5')
model.save_weights('mnist_cnn_weight.h5')
print("Model and Weights succesfully Saved-mnist_cnn.h5")

#랜덤 이미지에대해 적용해본다
random_image = x_test[np.random.choice(len(x_test))] 
test_image = np.expand_dims(random_image, axis = 0) 

predict = model.predict(test_image)
print('predict ',predict, np.argmax(predict, axis=1)) 

plt.imshow(test_image[0], cmap='Greys')
plt.show()

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import cv2

#본인의 손글씨 이미지를 불러온다.
image = cv2.imread('./number.png', cv2.IMREAD_GRAYSCALE)
image = image/255.0

#바로 위에서 학습한 모델을 불러온다
model = tf.keras.models.load_model('mnist_cnn.h5')

#CNN모델에 넣기위해  이미지를 3차원 배열로 만들어준다
test_image = np.expand_dims(image, axis = 0) 

#모델을 적용하고, 결과를 이미지와함께 출력한다.
predict = model.predict(test_image)
print('predict ',predict, np.argmax(predict, axis=1)) 

plt.imshow(test_image[0], cmap='Greys')
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import numpy as np
import matplotlib.pyplot as plt

#데이터셋을 불러오고 압축을 푼다
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip' 
path_to_zip = tf.keras.utils.get_file('cats_and_dogs.zip', origin=_URL, extract=True) 
PATH = os.path.join(os.path.dirname(path_to_zip), 'cats_and_dogs_filtered')

#학습용과 테스트용으로 나눠가져온다
train_dir = os.path.join(PATH, 'train')
validation_dir = os.path.join(PATH, 'validation')

#다시 개와 고양이로 나눠 저장한다
train_cats_dir = os.path.join(train_dir, 'cats')  
train_dogs_dir = os.path.join(train_dir, 'dogs')

validation_cats_dir = os.path.join(validation_dir, 'cats')  
validation_dogs_dir = os.path.join(validation_dir, 'dogs') 

#각 학습,테스트,개,고양이 데이터이미지의 수를 확인한다
num_cats_tr = len(os.listdir(train_cats_dir))
num_dogs_tr = len(os.listdir(train_dogs_dir))
num_cats_val = len(os.listdir(validation_cats_dir))
num_dogs_val = len(os.listdir(validation_dogs_dir))
total_train = num_cats_tr + num_dogs_tr 
total_val = num_cats_val + num_dogs_val
print('total training cat images:', num_cats_tr)
print('total training dog images:', num_dogs_tr)
print('total validation cat images:', num_cats_val)
print('total validation dog images:', num_dogs_val)
print("--")
print("Total training images:", total_train)
print("Total validation images:", total_val)

#학습용 parameter를 설정한다.
batch_size = 32 
epochs = 15 
IMG_HEIGHT = 150 
IMG_WIDTH = 150

train_image_generator = ImageDataGenerator(rescale=1./255) 
validation_image_generator = ImageDataGenerator(rescale=1./255)

image_gen_train = ImageDataGenerator(rescale=1./255, 
                                     rotation_range=45, 
                                     width_shift_range=.15, 
                                     height_shift_range=.15, 
                                     horizontal_flip=True, 
                                     zoom_range=0.5
)

train_data_gen = image_gen_train.flow_from_directory(batch_size=batch_size,
                                                     directory=train_dir, shuffle=True,
                                                     target_size=(IMG_HEIGHT, IMG_WIDTH), 
                                                     class_mode='binary')


val_data_gen = validation_image_generator.flow_from_directory(batch_size=batch_size,
                                                              directory=validation_dir,
                                                              target_size=(IMG_HEIGHT, IMG_WIDTH), 
                                                              class_mode='binary')

augmented_images = [train_data_gen[0][0][0] for i in range(5)] 
plotImages(augmented_images)

"""model = Sequential([
    Conv2D(16, 3, padding='same', activation='relu', 
           input_shape=(IMG_HEIGHT, IMG_WIDTH ,3)),
    MaxPooling2D(),
    Dropout(0.2),
    Conv2D(32, 3, padding='same', activation='relu'), 
    MaxPooling2D(),
    Dropout(0.2),
    Conv2D(64, 3, padding='same', 
           activation='relu'), 
    MaxPooling2D(),
    Dropout(0.2),
    Flatten(),
    Dense(512, activation='relu'), 
    Dense(1, activation='sigmoid')
])
"""
vgg = tf.keras.applications.VGG19(include_top=False, 
                                  weights='imagenet', 
                                  input_shape=(IMG_HEIGHT, IMG_WIDTH ,3))

model_vgg = Sequential([
    vgg,
    tf.keras.layers.GlobalAveragePooling2D(), 
    Dense(1, activation='sigmoid')
])

"""model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
"""

adam = tf.keras.optimizers.Adam(lr=0.0001) 
model_vgg.compile(optimizer=adam,loss='binary_crossentropy', metrics=['accuracy'])
model_vgg.summary()

history = model_vgg.fit_generator( 
    train_data_gen,
    steps_per_epoch=total_train // batch_size, 
    epochs=epochs,
    validation_data=val_data_gen, 
    validation_steps=total_val // batch_size, 
    verbose=2
)

acc = history.history['acc']
val_acc = history.history['val_acc'] 

loss = history.history['loss']
val_loss = history.history['val_loss'] 

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
